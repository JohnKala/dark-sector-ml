# %% [markdown]
# # Performance Comparison Analysis
#
# This notebook provides a comprehensive comparison of different model architectures and training strategies.
#
# ## Analysis Objectives
# - Compare standard vs adversarial training
# - Analyze cross-model performance
# - Generate performance reports
# - Create publication-ready figures

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path for imports
import sys
sys.path.append('../../src')

from evaluation.comparison import compare_standard_vs_adversarial
from evaluation.cross_evaluation import evaluate_cross_model_performance
from visualization.comparison_plots import plot_cross_model_heatmap
from utils.reporting import generate_comparison_report

# %% [markdown]
# ## Performance Analysis

# %%
# Performance comparison analysis
print("Performance comparison analysis goes here")
