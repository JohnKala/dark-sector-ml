# %% [markdown]
# # Data Loading Tutorial
#
# This tutorial demonstrates how to load and preprocess dark sector data using the project's data loading utilities.
#
# ## Learning Objectives
# - Understand the data structure
# - Learn to use the data loading functions
# - Preprocess data for ML models
# - Create train/validation/test splits

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Add src to path for imports
import sys
sys.path.append('../../src')

from data.loader import load_dataset, extract_parameters
from data.preprocessor import create_scaled_features, create_dataset
from data.preparation import prepare_ml_dataset, prepare_deepsets_data

# %% [markdown]
# ## Step 1: Loading Raw Data

# %%
# Example data loading
# Replace with your actual data path
data_path = '../../data/raw/example_data.hdf5'

# data = load_dataset(data_path)
print("Load your HDF5 data files here")

# %% [markdown]
# ## Step 2: Data Preprocessing

# %%
# Preprocessing steps
print("Data preprocessing examples go here")
